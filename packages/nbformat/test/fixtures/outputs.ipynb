# %%
print('hello')
print('world')
# Out:
# hello
# world
# warn

# %%
plt.plot([1,2])

# %%
df
# Out:
#    a
# 0  1

# %%
1/0
# Out:
# ZeroDivisionError Traceback
# 1/0

# %% [markdown]
# ![a](attachment:a.png)

# %% [raw]
# raw text
